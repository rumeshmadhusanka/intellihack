# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# <h2>Understanding the Dataset

# %%
df = pd.read_csv('data.csv')
df.head(3)
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   3       145   233    1        0      150      0      2.3
# 1   37    male   2       130   250    0        1      187      0      3.5
# 2   41  female   1       130   204    0        0      172      0      1.4
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1

# %% [markdown]
# The dataset contains the following features:
# 1. age: (in years)
# 2. sex: (male, female)
# 3. cp: chest pain type
# 4. trestbps: resting blood pressure (in mm Hg on admission to the hospital)
# 5. chol: serum cholestoral in mg/dl
# 6. fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# 7. restecg: resting electrocardiographic results
# 8. thalach: maximum heart rate achieved
# 9. exang: exercise induced angina (1 = yes; 0 = no)
# 10. oldpeak: ST depression induced by exercise relative to rest
# 11. slope: the slope of the peak exercise ST segment
# 12. ca: number of major vessels (0-3) colored by flourosopy
# 13. thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
# 14. target: 1 or 0

# %%
df.dtypes #data types
# Out:
# age           int64
# sex          object
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.shape #no of rows and columns
# Out:
# (303, 14)

# %%
df.describe() #summery of the data set
# Out:
#               age          cp    trestbps        chol         fbs     restecg  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.966997  131.623762  246.264026    0.148515    0.528053
# std      9.082101    1.032052   17.538143   51.830751    0.356198    0.525860
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     47.500000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     55.000000    1.000000  130.000000  240.000000    0.000000    1.000000
# 75%     61.000000    2.000000  140.000000  274.500000    0.000000    1.000000
# max     77.000000    3.000000  200.000000  564.000000    1.000000    2.000000
#
#           thalach       exang     oldpeak       slope          ca        thal  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   149.646865    0.326733    1.039604    1.399340    0.729373    2.313531
# std     22.905161    0.469794    1.161075    0.616226    1.022606    0.612277
# min     71.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    133.500000    0.000000    0.000000    1.000000    0.000000    2.000000
# 50%    153.000000    0.000000    0.800000    1.000000    0.000000    2.000000
# 75%    166.000000    1.000000    1.600000    2.000000    1.000000    3.000000
# max    202.000000    1.000000    6.200000    2.000000    4.000000    3.000000
#
#            target
# count  303.000000
# mean     0.544554
# std      0.498835
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# **The features described in the above data set are**
#
# 1. Count = Number of non-empty rows in a feature
# 2. Mean  = Mean value of a feature
# 3. Std   = Standard Deviation Value of a feature
# 4. Min   = Minimum value of a feature
# 5. 25%, 50%, and 75% = Percentile/quartile of each feature
# 6. Max   = Maximum value of a feature

# %% [markdown]
# <h1>Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns #

# %% [markdown]
# <h2>Plot Features

# %%
sns.distplot(tuple(df['thalach']), kde = False, bins=30, color='blue')

# %%
sns.distplot(tuple(df['chol']), kde=False,color='red')
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(20,14))
sns.countplot(x='age',data = df, hue = 'target',palette='GnBu')
plt.show()

# %% [markdown]
# <h2>Scatter Plots

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='trestbps',y='thalach',data=df, hue='target')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='target',y='thalach',data=df, hue='sex')
plt.show()

# %% [markdown]
# <h2>Swarm Plot

# %%
plt.figure(figsize=(8,6))
sns.swarmplot(x='target',y='thalach',data=df, hue='sex')
plt.show()

# %% [markdown]
# <h2>Box Plot

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='target',y='thalach',data=df, hue='sex')
plt.show()

# %% [markdown]
# <h2>Violin Plot

# %%
plt.figure(figsize=(8,6))
sns.violinplot(x='sex',y='thalach',data=df, hue='target', split=True)
plt.show()

# %% [markdown]
# <h1>Data Preprocessing

# %% [markdown]
# <h2>Handling Missing Values

# %%
df = df.isnull().sum() #Find null values in the dataset. Fill them or drop them

# %% [markdown]
# <h3>Drop NULL Value Columns

# %%
df=df.dropna() #Remove null values

# %% [markdown]
# <h3>Fill NULL Values

# %%
df=df.fillna(method='bfill') #Copy the previous value for the null value : Ex: For missing time

# %% [markdown]
# <h3>Some Other Methods of Filling Null Values</h3>
#
# **df.fillna(0)** - fill with "0" <br>
# **df.fillna(method='bfill')** - fill with before value <br>
# **df.fillna({'age': 10, 'sex': 1, 'cp': 1, 'trestbps': 130})** - fill with given values

# %% [markdown]
# <h2>Outlier Removal

# %% [markdown]
# <h3>Using Z-Score Approach

# %%
from scipy import stats

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='trestbps',y='thalach',data=df, hue='target')
plt.show()

# %%
df2 = df[(np.abs(stats.zscore(df['thalach'])) < 3)] #using the z score method
df2 = df2[(np.abs(stats.zscore(df2['trestbps'])) < 3)] #3:data points more than 3 standard deviation are removed.

# %%
df2.shape[0]
# Out:
# 300

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='trestbps',y='thalach',data=df2, hue='target')
plt.show()

# %% [markdown]
# <h3>Using Quantile Approach

# %%
q = df['thalach'].quantile(0.7) #quantile value
df3 = df[df['thalach'] < q]#Remove data points less than quantile value.

q = df3['trestbps'].quantile(0.99)
df3 = df3[df3['trestbps'] < q] #when removing noise use another dataset by assinging to another var

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='trestbps',y='thalach',data=df3, hue='target')
plt.show()

# %%
df3.shape[0]
# Out:
# 205

# %%
df = df3

# %% [markdown]
# <h3>Encoding Categorical Variables

# %%
from sklearn import preprocessing

# %%
df.head(3)
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   3       145   233    1        0      150      0      2.3
# 5   57    male   0       140   192    0        1      148      0      0.4
# 6   56  female   1       140   294    0        0      153      0      1.3
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 5      1   0     1       1
# 6      1   0     2       1

# %%
df.describe()
# Out:
#               age          cp    trestbps        chol        fbs     restecg  \
# count  205.000000  205.000000  205.000000  205.000000  205.00000  205.000000
# mean    56.609756    0.819512  131.253659  248.843902    0.15122    0.482927
# std      8.312163    1.039235   17.093860   54.403585    0.35914    0.529476
# min     35.000000    0.000000   94.000000  131.000000    0.00000    0.000000
# 25%     51.000000    0.000000  120.000000  212.000000    0.00000    0.000000
# 50%     58.000000    0.000000  130.000000  244.000000    0.00000    0.000000
# 75%     62.000000    2.000000  140.000000  278.000000    0.00000    1.000000
# max     77.000000    3.000000  178.000000  564.000000    1.00000    2.000000
#
#           thalach       exang     oldpeak       slope          ca        thal  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   138.780488    0.409756    1.259024    1.273171    0.843902    2.351220
# std     18.754231    0.492993    1.194710    0.596979    1.036124    0.674145
# min     71.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    126.000000    0.000000    0.200000    1.000000    0.000000    2.000000
# 50%    143.000000    0.000000    1.000000    1.000000    0.000000    2.000000
# 75%    154.000000    1.000000    1.900000    2.000000    1.000000    3.000000
# max    162.000000    1.000000    6.200000    2.000000    4.000000    3.000000
#
#            target
# count  205.000000
# mean     0.439024
# std      0.497483
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
label_encoder = preprocessing.LabelEncoder() #Encode strings 
#Because we cannot keep strings. Label encoder will encode then to numbers for us. WE can manually do it too.

# %%
df['sex'] = label_encoder.fit_transform(df['sex'])
df.head(3)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 5   0     1       1
# 6   0     2       1

# %% [markdown]
# <h3>Data Normalization

# %%
x = df[['chol', 'thalach']].values# ex: 6000to 1000 => 10=>0 scaling shoul be done
#put all the needed columns in a list.
min_max_scaler = preprocessing.MinMaxScaler()#Scalar will scale them to the requited amount
df_scaled = min_max_scaler.fit_transform(x)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
df.head(5)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 8    52    1   2       172   199    1        1      162      0      0.5
# 10   54    1   0       140   239    0        1      160      0      1.2
#
#     slope  ca  thal  target
# 0       0   0     1       1
# 5       1   0     1       1
# 6       1   0     2       1
# 8       2   0     3       1
# 10      2   0     2       1

# %%
pd.DataFrame(df_scaled).head(5)
# Out:
#           0         1
# 0  0.235566  0.868132
# 1  0.140878  0.846154
# 2  0.376443  0.901099
# 3  0.157044  1.000000
# 4  0.249423  0.978022

# %% [markdown]
# <h2>Feature Engineering

# %% [markdown]
# <h3>Correlation Analysis

# %%
# Correlation = one can be derived from other data. We should remove them.
#Correlation 0.9 or above: high correlation
#correlation 1: the same data
#Find good feature black ones are good to go.
plt.figure(figsize=(18,18))
plt.rcParams["axes.labelsize"] = 20
sns.set(font_scale=1.4)
sns.heatmap(df.corr(), annot = True ,linewidths=.1)
plt.show()

# %%
#Handwitten func. But can use another too.
def find_correlation(data, threshold=0.9):
    corr_mat = data.corr()
    corr_mat.loc[:, :] = np.tril(corr_mat, k=-1)
    already_in = set()
    result = []
    for col in corr_mat:
        perfect_corr = corr_mat[col][abs(corr_mat[col])> threshold].index.tolist()
        if perfect_corr and col not in already_in:
            already_in.update(set(perfect_corr))
            perfect_corr.append(col)
            result.append(perfect_corr)
    select_nested = [f[1:] for f in result]
    select_flat = [i for j in select_nested for i in j]
    return select_flat

# %%
columns_to_drop = find_correlation(df.drop(columns=['target']) , 0.7)
df4 = df.drop(columns=columns_to_drop)# dropping features for easy use.

# %%
df4
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 8     52    1   2       172   199    1        1      162      0      0.5
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# 13    64    1   3       110   211    0        0      144      1      1.8
# 14    58    0   3       150   283    1        0      162      0      1.0
# 15    50    0   2       120   219    0        1      158      0      1.6
# 17    66    0   3       150   226    0        1      114      0      2.6
# 19    69    0   3       140   239    0        1      151      0      1.8
# 20    59    1   0       135   234    0        1      161      0      0.5
# 23    61    1   2       150   243    1        1      137      1      1.0
# 25    71    0   1       160   302    0        1      162      0      0.4
# 26    59    1   2       150   212    1        1      157      0      1.6
# 27    51    1   2       110   175    0        1      123      0      0.6
# 28    65    0   2       140   417    1        0      157      0      0.8
# 29    53    1   2       130   197    1        0      152      0      1.2
# 31    65    1   0       120   177    0        1      140      0      0.4
# 33    54    1   2       125   273    0        0      152      0      0.5
# 34    51    1   3       125   213    0        0      125      1      1.4
# 35    46    0   2       142   177    0        0      160      1      1.4
# 38    65    0   2       155   269    0        1      148      0      0.8
# 39    65    0   2       160   360    0        0      151      0      0.8
# 40    51    0   2       140   308    0        0      142      0      1.5
# 42    45    1   0       104   208    0        0      148      1      3.0
# 43    53    0   0       130   264    0        0      143      0      0.4
# 47    47    1   2       138   257    0        0      156      0      0.0
# 48    53    0   2       128   216    0        0      115      0      0.0
# 49    53    0   0       138   234    0        0      160      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 269   56    1   0       130   283    1        0      103      1      1.6
# 270   46    1   0       120   249    0        0      144      0      0.8
# 271   61    1   3       134   234    0        1      145      0      2.6
# 272   67    1   0       120   237    0        1       71      0      1.0
# 273   58    1   0       100   234    0        1      156      0      0.1
# 274   47    1   0       110   275    0        0      118      1      1.0
# 276   58    1   0       146   218    0        1      105      0      2.0
# 277   57    1   1       124   261    0        1      141      0      0.3
# 278   58    0   1       136   319    1        0      152      0      0.0
# 279   61    1   0       138   166    0        0      125      1      3.6
# 280   42    1   0       136   315    0        1      125      1      1.8
# 281   52    1   0       128   204    1        1      156      1      1.0
# 282   59    1   2       126   218    1        1      134      0      2.2
# 284   61    1   0       140   207    0        0      138      1      1.9
# 285   46    1   0       140   311    0        1      120      1      1.8
# 286   59    1   3       134   204    0        1      162      0      0.8
# 288   57    1   0       110   335    0        1      143      1      3.0
# 289   55    0   0       128   205    0        2      130      1      2.0
# 290   61    1   0       148   203    0        1      161      0      0.0
# 291   58    1   0       114   318    0        2      140      0      4.4
# 292   58    0   0       170   225    1        0      146      1      2.8
# 293   67    1   2       152   212    0        0      150      0      0.8
# 294   44    1   0       120   169    0        1      144      1      2.8
# 295   63    1   0       140   187    0        0      144      1      4.0
# 296   63    0   0       124   197    0        1      136      1      0.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 5        1   0     1       1
# 6        1   0     2       1
# 8        2   0     3       1
# 10       2   0     2       1
# 11       2   0     2       1
# 13       1   0     2       1
# 14       2   0     2       1
# 15       1   0     2       1
# 17       0   0     2       1
# 19       2   2     2       1
# 20       1   0     3       1
# 23       1   0     2       1
# 25       2   2     2       1
# 26       2   0     2       1
# 27       2   0     2       1
# 28       2   1     2       1
# 29       0   0     2       1
# 31       2   0     3       1
# 33       0   1     2       1
# 34       2   1     2       1
# 35       0   0     2       1
# 38       2   0     2       1
# 39       2   0     2       1
# 40       2   1     2       1
# 42       1   0     2       1
# 43       1   0     2       1
# 47       2   0     2       1
# 48       2   0     0       1
# 49       2   0     2       1
# ..     ...  ..   ...     ...
# 269      0   0     3       0
# 270      2   0     3       0
# 271      1   2     2       0
# 272      1   0     2       0
# 273      2   1     3       0
# 274      1   1     2       0
# 276      1   1     3       0
# 277      2   0     3       0
# 278      2   2     2       0
# 279      1   1     2       0
# 280      1   0     1       0
# 281      1   0     0       0
# 282      1   1     1       0
# 284      2   1     3       0
# 285      1   2     3       0
# 286      2   2     2       0
# 288      1   1     3       0
# 289      1   1     3       0
# 290      2   1     3       0
# 291      0   3     1       0
# 292      1   2     1       0
# 293      1   0     3       0
# 294      0   0     1       0
# 295      2   2     3       0
# 296      1   0     2       0
# 297      1   2     1       0
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
#
# [205 rows x 14 columns]

# %%
corr = df.corr()
linear_features=abs(corr).target.drop('target').sort_values(ascending=False)[:5].keys()

# %%
abs(corr).target.drop('target').sort_values(ascending=False)[:5].plot(kind='barh') #Best features.

# %% [markdown]
# <h3>Using Random Forest Classifier to Identify Important Features

# %%
#Descision Trees
#Random Forest for regression and identifying outliers
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
y = df.copy(deep=True)['target']
model = rf.fit(df.drop('target', axis=1),y)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
importance = rf.feature_importances_
feat_importances_act = pd.Series(importance, index=df.drop('target', axis=1).columns)
feat_importances = feat_importances_act.nlargest(20)
feat_importances.plot(kind='barh')
#use high entropy features for decision trees
#Dont shuffle time series data

# %% [markdown]
# <h3>Convert Categorical Variables into Dummy Variables

# %%
df.dtypes #dont confuse the model between numerical and categorical variables.
# Out:
# age           int64
# sex           int32
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df['sex'] = df['sex'].astype('object')
df['cp'] = df['cp'].astype('object')
df['fbs'] = df['fbs'].astype('object')
df['restecg'] = df['restecg'].astype('object')
df['exang'] = df['exang'].astype('object')
df['slope'] = df['slope'].astype('object')
df['thal'] = df['thal'].astype('object')
df.dtypes
# Out:
# age           int64
# sex          object
# cp           object
# trestbps      int64
# chol          int64
# fbs          object
# restecg      object
# thalach       int64
# exang        object
# oldpeak     float64
# slope        object
# ca            int64
# thal         object
# target        int64
# dtype: object

# %%
df.head(10)
# Out:
#     age sex cp  trestbps  chol fbs restecg  thalach exang  oldpeak slope  ca  \
# 0    63   1  3       145   233   1       0      150     0      2.3     0   0
# 5    57   1  0       140   192   0       1      148     0      0.4     1   0
# 6    56   0  1       140   294   0       0      153     0      1.3     1   0
# 8    52   1  2       172   199   1       1      162     0      0.5     2   0
# 10   54   1  0       140   239   0       1      160     0      1.2     2   0
# 11   48   0  2       130   275   0       1      139     0      0.2     2   0
# 13   64   1  3       110   211   0       0      144     1      1.8     1   0
# 14   58   0  3       150   283   1       0      162     0      1.0     2   0
# 15   50   0  2       120   219   0       1      158     0      1.6     1   0
# 17   66   0  3       150   226   0       1      114     0      2.6     0   0
#
#    thal  target
# 0     1       1
# 5     1       1
# 6     2       1
# 8     3       1
# 10    2       1
# 11    2       1
# 13    2       1
# 14    2       1
# 15    2       1
# 17    2       1

# %%
df_1 = pd.get_dummies(df, drop_first=True)
df_1.head()
 #Convert sex to 1 or 0 : binary variables
# Create as many features, dummies, reduce them
# Out:
#     age  trestbps  chol  thalach  oldpeak  ca  target  sex_1  cp_1  cp_2  \
# 0    63       145   233      150      2.3   0       1      1     0     0
# 5    57       140   192      148      0.4   0       1      1     0     0
# 6    56       140   294      153      1.3   0       1      0     1     0
# 8    52       172   199      162      0.5   0       1      1     0     1
# 10   54       140   239      160      1.2   0       1      1     0     0
#
#     cp_3  fbs_1  restecg_1  restecg_2  exang_1  slope_1  slope_2  thal_1  \
# 0      1      1          0          0        0        0        0       1
# 5      0      0          1          0        0        1        0       1
# 6      0      0          0          0        0        1        0       0
# 8      0      1          1          0        0        0        1       0
# 10     0      0          1          0        0        0        1       0
#
#     thal_2  thal_3
# 0        0       0
# 5        0       0
# 6        1       0
# 8        0       1
# 10       1       0

# %%
df_1
# Out:
#      age  trestbps  chol  thalach  oldpeak  ca  target  sex_1  cp_1  cp_2  \
# 0     63       145   233      150      2.3   0       1      1     0     0
# 5     57       140   192      148      0.4   0       1      1     0     0
# 6     56       140   294      153      1.3   0       1      0     1     0
# 8     52       172   199      162      0.5   0       1      1     0     1
# 10    54       140   239      160      1.2   0       1      1     0     0
# 11    48       130   275      139      0.2   0       1      0     0     1
# 13    64       110   211      144      1.8   0       1      1     0     0
# 14    58       150   283      162      1.0   0       1      0     0     0
# 15    50       120   219      158      1.6   0       1      0     0     1
# 17    66       150   226      114      2.6   0       1      0     0     0
# 19    69       140   239      151      1.8   2       1      0     0     0
# 20    59       135   234      161      0.5   0       1      1     0     0
# 23    61       150   243      137      1.0   0       1      1     0     1
# 25    71       160   302      162      0.4   2       1      0     1     0
# 26    59       150   212      157      1.6   0       1      1     0     1
# 27    51       110   175      123      0.6   0       1      1     0     1
# 28    65       140   417      157      0.8   1       1      0     0     1
# 29    53       130   197      152      1.2   0       1      1     0     1
# 31    65       120   177      140      0.4   0       1      1     0     0
# 33    54       125   273      152      0.5   1       1      1     0     1
# 34    51       125   213      125      1.4   1       1      1     0     0
# 35    46       142   177      160      1.4   0       1      0     0     1
# 38    65       155   269      148      0.8   0       1      0     0     1
# 39    65       160   360      151      0.8   0       1      0     0     1
# 40    51       140   308      142      1.5   1       1      0     0     1
# 42    45       104   208      148      3.0   0       1      1     0     0
# 43    53       130   264      143      0.4   0       1      0     0     0
# 47    47       138   257      156      0.0   0       1      1     0     1
# 48    53       128   216      115      0.0   0       1      0     0     1
# 49    53       138   234      160      0.0   0       1      0     0     0
# ..   ...       ...   ...      ...      ...  ..     ...    ...   ...   ...
# 269   56       130   283      103      1.6   0       0      1     0     0
# 270   46       120   249      144      0.8   0       0      1     0     0
# 271   61       134   234      145      2.6   2       0      1     0     0
# 272   67       120   237       71      1.0   0       0      1     0     0
# 273   58       100   234      156      0.1   1       0      1     0     0
# 274   47       110   275      118      1.0   1       0      1     0     0
# 276   58       146   218      105      2.0   1       0      1     0     0
# 277   57       124   261      141      0.3   0       0      1     1     0
# 278   58       136   319      152      0.0   2       0      0     1     0
# 279   61       138   166      125      3.6   1       0      1     0     0
# 280   42       136   315      125      1.8   0       0      1     0     0
# 281   52       128   204      156      1.0   0       0      1     0     0
# 282   59       126   218      134      2.2   1       0      1     0     1
# 284   61       140   207      138      1.9   1       0      1     0     0
# 285   46       140   311      120      1.8   2       0      1     0     0
# 286   59       134   204      162      0.8   2       0      1     0     0
# 288   57       110   335      143      3.0   1       0      1     0     0
# 289   55       128   205      130      2.0   1       0      0     0     0
# 290   61       148   203      161      0.0   1       0      1     0     0
# 291   58       114   318      140      4.4   3       0      1     0     0
# 292   58       170   225      146      2.8   2       0      0     0     0
# 293   67       152   212      150      0.8   0       0      1     0     1
# 294   44       120   169      144      2.8   0       0      1     0     0
# 295   63       140   187      144      4.0   2       0      1     0     0
# 296   63       124   197      136      0.0   0       0      0     0     0
# 297   59       164   176       90      1.0   2       0      1     0     0
# 298   57       140   241      123      0.2   0       0      0     0     0
# 299   45       110   264      132      1.2   0       0      1     0     0
# 300   68       144   193      141      3.4   2       0      1     0     0
# 301   57       130   131      115      1.2   1       0      1     0     0
#
#      cp_3  fbs_1  restecg_1  restecg_2  exang_1  slope_1  slope_2  thal_1  \
# 0       1      1          0          0        0        0        0       1
# 5       0      0          1          0        0        1        0       1
# 6       0      0          0          0        0        1        0       0
# 8       0      1          1          0        0        0        1       0
# 10      0      0          1          0        0        0        1       0
# 11      0      0          1          0        0        0        1       0
# 13      1      0          0          0        1        1        0       0
# 14      1      1          0          0        0        0        1       0
# 15      0      0          1          0        0        1        0       0
# 17      1      0          1          0        0        0        0       0
# 19      1      0          1          0        0        0        1       0
# 20      0      0          1          0        0        1        0       0
# 23      0      1          1          0        1        1        0       0
# 25      0      0          1          0        0        0        1       0
# 26      0      1          1          0        0        0        1       0
# 27      0      0          1          0        0        0        1       0
# 28      0      1          0          0        0        0        1       0
# 29      0      1          0          0        0        0        0       0
# 31      0      0          1          0        0        0        1       0
# 33      0      0          0          0        0        0        0       0
# 34      1      0          0          0        1        0        1       0
# 35      0      0          0          0        1        0        0       0
# 38      0      0          1          0        0        0        1       0
# 39      0      0          0          0        0        0        1       0
# 40      0      0          0          0        0        0        1       0
# 42      0      0          0          0        1        1        0       0
# 43      0      0          0          0        0        1        0       0
# 47      0      0          0          0        0        0        1       0
# 48      0      0          0          0        0        0        1       0
# 49      0      0          0          0        0        0        1       0
# ..    ...    ...        ...        ...      ...      ...      ...     ...
# 269     0      1          0          0        1        0        0       0
# 270     0      0          0          0        0        0        1       0
# 271     1      0          1          0        0        1        0       0
# 272     0      0          1          0        0        1        0       0
# 273     0      0          1          0        0        0        1       0
# 274     0      0          0          0        1        1        0       0
# 276     0      0          1          0        0        1        0       0
# 277     0      0          1          0        0        0        1       0
# 278     0      1          0          0        0        0        1       0
# 279     0      0          0          0        1        1        0       0
# 280     0      0          1          0        1        1        0       1
# 281     0      1          1          0        1        1        0       0
# 282     0      1          1          0        0        1        0       1
# 284     0      0          0          0        1        0        1       0
# 285     0      0          1          0        1        1        0       0
# 286     1      0          1          0        0        0        1       0
# 288     0      0          1          0        1        1        0       0
# 289     0      0          0          1        1        1        0       0
# 290     0      0          1          0        0        0        1       0
# 291     0      0          0          1        0        0        0       1
# 292     0      1          0          0        1        1        0       1
# 293     0      0          0          0        0        1        0       0
# 294     0      0          1          0        1        0        0       1
# 295     0      0          0          0        1        0        1       0
# 296     0      0          1          0        1        1        0       0
# 297     0      1          0          0        0        1        0       1
# 298     0      0          1          0        1        1        0       0
# 299     1      0          1          0        0        1        0       0
# 300     0      1          1          0        0        1        0       0
# 301     0      0          1          0        1        1        0       0
#
#      thal_2  thal_3
# 0         0       0
# 5         0       0
# 6         1       0
# 8         0       1
# 10        1       0
# 11        1       0
# 13        1       0
# 14        1       0
# 15        1       0
# 17        1       0
# 19        1       0
# 20        0       1
# 23        1       0
# 25        1       0
# 26        1       0
# 27        1       0
# 28        1       0
# 29        1       0
# 31        0       1
# 33        1       0
# 34        1       0
# 35        1       0
# 38        1       0
# 39        1       0
# 40        1       0
# 42        1       0
# 43        1       0
# 47        1       0
# 48        0       0
# 49        1       0
# ..      ...     ...
# 269       0       1
# 270       0       1
# 271       1       0
# 272       1       0
# 273       0       1
# 274       1       0
# 276       0       1
# 277       0       1
# 278       1       0
# 279       1       0
# 280       0       0
# 281       0       0
# 282       0       0
# 284       0       1
# 285       0       1
# 286       1       0
# 288       0       1
# 289       0       1
# 290       0       1
# 291       0       0
# 292       0       0
# 293       0       1
# 294       0       0
# 295       0       1
# 296       1       0
# 297       0       0
# 298       0       1
# 299       0       1
# 300       0       1
# 301       0       1
#
# [205 rows x 20 columns]

# %% [markdown]
# <h1>Applying ML Models

# %% [markdown]
# <h2>Split Train and Test sets

# %%
#Why split them as train and test: Train-make the model,Test-validate the model
#Times series data: Never shuffle data
#Random sapmling is OK in other types of data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.drop('target',1), df['target'], test_size = .2, random_state=10)

# %%
X_train.head()
# Out:
#      age sex cp  trestbps  chol fbs restecg  thalach exang  oldpeak slope  ca  \
# 250   51   1  0       140   298   0       1      122     1      4.2     1   3
# 175   40   1  0       110   167   0       0      114     1      2.0     1   0
# 210   57   1  2       128   229   0       0      150     0      0.4     1   1
# 87    46   1  1       101   197   1       1      156     0      0.0     2   0
# 166   67   1  0       120   229   0       0      129     1      2.6     1   2
#
#     thal
# 250    3
# 175    3
# 210    3
# 87     3
# 166    3

# %% [markdown]
# <h2>Random Forest Classifier

# %%
#Build models form random forest classifier
#Model is like an algorithm
from sklearn.metrics import accuracy_score
model = RandomForestClassifier(max_depth=20)
model.fit(X_train, y_train)
predictions = model.predict(X_test)
# cla_pred.append(accuracy_score(y_test,predictions))
print(accuracy_score(y_test,predictions))#Accurate? how much
# Out:
# 0.6829268292682927
# D:\Anaconda\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
importance = model.feature_importances_
feat_importances_act = pd.Series(importance, index=X_train.columns)
feat_importances = feat_importances_act.nlargest(20)
feat_importances.plot(kind='barh')

# %% [markdown]
# <h3> Other Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
#from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

#these are the models
#More depth may lead to over fitting
classifiers=[['Logistic Regression :',LogisticRegression()],
       ['Decision Tree Classification :',DecisionTreeClassifier()],
       ['Gradient Boosting Classification :', GradientBoostingClassifier()],
       ['Ada Boosting Classification :',AdaBoostClassifier()],
       ['Extra Tree Classification :', ExtraTreesClassifier()],
       ['K-Neighbors Classification :',KNeighborsClassifier()],
       ['Support Vector Classification :',SVC()],
       ['Gaussian Naive Bayes :',GaussianNB()]]
cla_pred=[]
for name,model in classifiers:
    model=model
    model.fit(X_train,y_train)
    predictions = model.predict(X_test)
    cla_pred.append(accuracy_score(y_test,predictions))
    print(name,accuracy_score(y_test,predictions))
# Out:
# D:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic Regression : 0.8536585365853658
# Decision Tree Classification : 0.6341463414634146
# Gradient Boosting Classification : 0.6829268292682927
# Ada Boosting Classification : 0.7317073170731707
# Extra Tree Classification : 0.6829268292682927
# K-Neighbors Classification : 0.5609756097560976
# Support Vector Classification : 0.4878048780487805
# Gaussian Naive Bayes : 0.8536585365853658
# D:\Anaconda\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# D:\Anaconda\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %% [markdown]
# <h2>Hyper Parameter Tuning

# %% [markdown]
# <h3>Using Grid Search

# %%
random.seed(100)
rfmodel = RandomForestClassifier()

# %%
#Hyperparameter tuning for Logistic Regression
random.seed(100)
from sklearn.model_selection import GridSearchCV
n_estimators = [10, 20, 50, 100]# no of trees
max_depth = [5,10,15,20]
#uses a greedy approach
hyperparameters = dict(max_depth=max_depth, n_estimators=n_estimators)
h_rfmodel = GridSearchCV(rfmodel, hyperparameters, cv=5, verbose=0)
best_logmodel=h_rfmodel.fit(df.drop('target', 1), df['target'])
print('Best Estimators:', best_logmodel.best_estimator_.get_params()['n_estimators'])
print('Best Max Depth:', best_logmodel.best_estimator_.get_params()['max_depth'])
#answer will change every time
#For less data random forest is not suitable
# Out:
# Best Estimators: 50
# Best Max Depth: 5

# %%
#Do it again
random.seed(100)
rfmodel = RandomForestClassifier(n_estimators=100, max_depth=10)
rfmodel.fit(X_train, y_train)
predictions = rfmodel.predict(X_test)
print(accuracy_score(y_test,predictions))
# Out:
# 0.7317073170731707

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# [[16  4]
#  [ 7 14]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.74        20
#            1       0.78      0.67      0.72        21
#
#    micro avg       0.73      0.73      0.73        41
#    macro avg       0.74      0.73      0.73        41
# weighted avg       0.74      0.73      0.73        41
#
# 0.7317073170731707

# %% [markdown]
# <h2> Model Evaluation

# %%
from sklearn.metrics import confusion_matrix
cm_lr = confusion_matrix(y_test,predictions)

# %%
plt.figure(figsize=(24,12))

plt.subplot(2,3,1)
plt.title("Logistic Regression Confusion Matrix")
sns.heatmap(cm_lr,annot=True,cmap="Blues",fmt="d",cbar=False)
plt.show()

# %% [markdown]
# ![350px-Precisionrecall.svg.png](attachment:350px-Precisionrecall.svg.png)

# %%
from sklearn.metrics import roc_curve, auc

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,rfmodel.predict_proba(X_test)[:,1])

# %%
import scikitplot as skplt
import matplotlib.pyplot as plt

skplt.metrics.plot_roc_curve(y_test,rfmodel.predict_proba(X_test), figsize = (20,20))
plt.figure(figsize=(40,18))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-63-8cc14506d737> in <module>
# ----> 1 import scikitplot as skplt
#       2 import matplotlib.pyplot as plt
#       3
#       4 skplt.metrics.plot_roc_curve(y_test,rfmodel.predict_proba(X_test), figsize = (20,20))
#       5 plt.figure(figsize=(40,18))
#
# ModuleNotFoundError: No module named 'scikitplot'
